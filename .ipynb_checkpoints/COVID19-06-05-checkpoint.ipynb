# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta
#from sklearn.metrics import mean_squared_error
#from scipy.stats import norm
#from scipy.optimize import curve_fit
#from scipy.optimize import fsolve
import matplotlib.pyplot as plt
#%matplotlib inline+
import folium
import json
import urllib.request

url_B = "https://data.brasil.io/dataset/covid19/caso.csv.gz"
url_G = "https://raw.githubusercontent.com/tbrugz/geodata-br/master/geojson/geojs-100-mun.json"

# %%
df = pd.read_csv(url_B, sep = ",")

# %%
req = urllib.request.urlopen(url_G)
content = req.read().decode('ansi')

geo = json.loads(content)

# %%
df_hoje = df.loc[df['is_last'] == True, :]

label = ["Dia", "Estado", "Casos Confirmados", "Óbitos Confirmados", "Incidência de Casos", "Mortalidade"]
color = ['#e8615d', '#f49436', '#2d9de5', '#3bbdbd', '#634792']

# %%
FMT = '%Y-%m-%d'

date = df['date']
df['date'] = date.map(lambda x : (datetime.strptime(x, FMT) - datetime.strptime("2020-02-25", FMT)).days)

# %%
df_estados = df.loc[df['city'].isnull(), :].drop(['city', 'place_type', 'city_ibge_code', 'order_for_place'], axis = 1)
df_estados.reset_index(drop = True, inplace = True)

df_Brasil = df_estados.drop(['is_last', 'estimated_population_2019', 'confirmed_per_100k_inhabitants', 'death_rate'], axis = 1)
df_Brasil = df_Brasil.groupby('date').sum()

# %%
Norte = ['AC', 'AM', 'AP', 'PA', 'RO', 'RR', 'TO']
Nordeste = ['AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'PI', 'RN', 'SE']
Sudeste = ['ES', 'MG', 'RJ', 'SP']
Sul = ['PR', 'RS', 'SC']
Centro_oeste = ['DF', 'GO', 'MT', 'MS']

Regiao = [Nordeste, Norte, Sudeste, Sul, Centro_oeste]

# %%
df_cidades = df.loc[df['place_type'].eq('city'), :].drop(['place_type', 'order_for_place'], axis = 1)
df_paraiba = df_cidades.loc[df_cidades['state'].eq('PB'), :].drop(['state'], axis = 1)
df_paraiba.reset_index(drop = True, inplace = True)

# %%
df_NE = []
df_N = []
df_SE = []
df_S = []
df_CO = []

df_regioes = [df_NE, df_N, df_SE, df_S, df_CO]

for r in range(len(Regiao)) :
    for e in range(len(Regiao[r])) :
        temp = df_cidades.loc[df_cidades['state'] == Regiao[r][e], :]#.drop(['estimated_population_2019'], axis = 1)
        df_regioes[r].append(temp)

df_regioes
# Out:
# [[       date state    city  confirmed  deaths  is_last  \
#   52808    70    AL  Anadia          1       1     True
#   52809    69    AL  Anadia          1       1    False
#   52810    68    AL  Anadia          1       1    False
#   52811    67    AL  Anadia          1       1    False
#   52812    66    AL  Anadia          1       1    False
#   ...     ...   ...     ...        ...     ...      ...
#   53500    57    AL  Viçosa          1       1    False
#   53501    56    AL  Viçosa          1       1    False
#   53502    55    AL  Viçosa          1       1    False
#   53503    54    AL  Viçosa          1       1    False
#   53504    53    AL  Viçosa          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   52808                    17545.0       2700201.0
#   52809                    17545.0       2700201.0
#   52810                    17545.0       2700201.0
#   52811                    17545.0       2700201.0
#   52812                    17545.0       2700201.0
#   ...                          ...             ...
#   53500                    25733.0       2709400.0
#   53501                    25733.0       2709400.0
#   53502                    25733.0       2709400.0
#   53503                    25733.0       2709400.0
#   53504                    25733.0       2709400.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   52808                         5.69963         1.0
#   52809                         5.69963         1.0
#   52810                         5.69963         1.0
#   52811                         5.69963         1.0
#   52812                         5.69963         1.0
#   ...                               ...         ...
#   53500                         3.88606         1.0
#   53501                         3.88606         1.0
#   53502                         3.88606         1.0
#   53503                         3.88606         1.0
#   53504                         3.88606         0.0
#
#   [697 rows x 10 columns],
#          date state       city  confirmed  deaths  is_last  \
#   39966    70    BA     Abaíra          4       0     True
#   39967    69    BA     Abaíra          4       0    False
#   39968    68    BA     Abaíra          1       0    False
#   39969    67    BA     Abaíra          1       0    False
#   39970    66    BA     Abaíra          1       0    False
#   ...     ...   ...        ...        ...     ...      ...
#   43547    60    BA  Água Fria          1       1    False
#   43548    59    BA  Água Fria          1       1    False
#   43549    58    BA  Água Fria          1       1    False
#   43550    57    BA  Água Fria          0       1    False
#   43551    56    BA  Água Fria          0       1    False
#
#          estimated_population_2019  city_ibge_code  \
#   39966                     8739.0       2900108.0
#   39967                     8739.0       2900108.0
#   39968                     8739.0       2900108.0
#   39969                     8739.0       2900108.0
#   39970                     8739.0       2900108.0
#   ...                          ...             ...
#   43547                    16970.0       2900405.0
#   43548                    16970.0       2900405.0
#   43549                    16970.0       2900405.0
#   43550                    16970.0       2900405.0
#   43551                    16970.0       2900405.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   39966                        45.77183         0.0
#   39967                        45.77183         0.0
#   39968                        11.44296         0.0
#   39969                        11.44296         0.0
#   39970                        11.44296         0.0
#   ...                               ...         ...
#   43547                         5.89275         1.0
#   43548                         5.89275         1.0
#   43549                         5.89275         1.0
#   43550                             NaN         0.0
#   43551                             NaN         0.0
#
#   [3586 rows x 10 columns],
#          date state           city  confirmed  deaths  is_last  \
#   36117    70    CE        Abaiara          0       0     True
#   36118    69    CE        Abaiara          0       0    False
#   36119    68    CE        Abaiara          0       0    False
#   36120    67    CE        Abaiara          0       0    False
#   36121    66    CE        Abaiara          0       0    False
#   ...     ...   ...            ...        ...     ...      ...
#   39426    48    CE  Várzea Alegre          1       0    False
#   39427    47    CE  Várzea Alegre          1       0    False
#   39428    46    CE  Várzea Alegre          1       0    False
#   39429    45    CE  Várzea Alegre          1       0    False
#   39430    44    CE  Várzea Alegre          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   36117                    11737.0       2300101.0
#   36118                    11737.0       2300101.0
#   36119                    11737.0       2300101.0
#   36120                    11737.0       2300101.0
#   36121                    11737.0       2300101.0
#   ...                          ...             ...
#   39426                    40721.0       2314003.0
#   39427                    40721.0       2314003.0
#   39428                    40721.0       2314003.0
#   39429                    40721.0       2314003.0
#   39430                    40721.0       2314003.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   36117                             NaN         0.0
#   36118                             NaN         0.0
#   36119                             NaN         0.0
#   36120                             NaN         0.0
#   36121                             NaN         0.0
#   ...                               ...         ...
#   39426                         2.45574         0.0
#   39427                         2.45574         0.0
#   39428                         2.45574         0.0
#   39429                         2.45574         0.0
#   39430                         2.45574         0.0
#
#   [3314 rows x 10 columns],
#          date state       city  confirmed  deaths  is_last  \
#   25798    70    MA  Alcântara          1       0     True
#   25799    69    MA  Alcântara          1       0    False
#   25800    68    MA  Alcântara          1       0    False
#   25801    67    MA  Alcântara          1       0    False
#   25802    66    MA  Alcântara          1       0    False
#   ...     ...   ...        ...        ...     ...      ...
#   27375    51    MA    Zé Doca          1       0    False
#   27376    50    MA    Zé Doca          1       0    False
#   27377    49    MA    Zé Doca          1       0    False
#   27378    48    MA    Zé Doca          1       0    False
#   27379    47    MA    Zé Doca          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   25798                    22097.0       2100204.0
#   25799                    22097.0       2100204.0
#   25800                    22097.0       2100204.0
#   25801                    22097.0       2100204.0
#   25802                    22097.0       2100204.0
#   ...                          ...             ...
#   27375                    51714.0       2114007.0
#   27376                    51714.0       2114007.0
#   27377                    51714.0       2114007.0
#   27378                    51714.0       2114007.0
#   27379                    51714.0       2114007.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   25798                         4.52550         0.0
#   25799                         4.52550         0.0
#   25800                         4.52550         0.0
#   25801                         4.52550         0.0
#   25802                         4.52550         0.0
#   ...                               ...         ...
#   27375                         1.93371         0.0
#   27376                         1.93371         0.0
#   27377                         1.93371         0.0
#   27378                         1.93371         0.0
#   27379                         1.93371         0.0
#
#   [1582 rows x 10 columns],
#          date state           city  confirmed  deaths  is_last  \
#   18212    70    PB  Alagoa Grande          3       0     True
#   18213    69    PB  Alagoa Grande          2       0    False
#   18214    68    PB  Alagoa Grande          2       0    False
#   18215    67    PB  Alagoa Grande          2       0    False
#   18216    66    PB  Alagoa Grande          2       0    False
#   ...     ...   ...            ...        ...     ...      ...
#   19183    68    PB      Umbuzeiro          2       1    False
#   19184    67    PB      Umbuzeiro          2       1    False
#   19185    66    PB      Umbuzeiro          3       1    False
#   19186    65    PB      Umbuzeiro          2       0    False
#   19187    64    PB      Umbuzeiro          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   18212                    28496.0       2500304.0
#   18213                    28496.0       2500304.0
#   18214                    28496.0       2500304.0
#   18215                    28496.0       2500304.0
#   18216                    28496.0       2500304.0
#   ...                          ...             ...
#   19183                     9907.0       2517001.0
#   19184                     9907.0       2517001.0
#   19185                     9907.0       2517001.0
#   19186                     9907.0       2517001.0
#   19187                     9907.0       2517001.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   18212                        10.52779      0.0000
#   18213                         7.01853      0.0000
#   18214                         7.01853      0.0000
#   18215                         7.01853      0.0000
#   18216                         7.01853      0.0000
#   ...                               ...         ...
#   19183                        20.18775      0.5000
#   19184                        20.18775      0.5000
#   19185                        30.28162      0.3333
#   19186                        20.18775      0.0000
#   19187                        10.09387      0.0000
#
#   [976 rows x 10 columns],
#          date state          city  confirmed  deaths  is_last  \
#   19243    70    PE  Abreu e Lima         87       4     True
#   19244    69    PE  Abreu e Lima         87       4    False
#   19245    68    PE  Abreu e Lima         87       4    False
#   19246    67    PE  Abreu e Lima         83       4    False
#   19247    66    PE  Abreu e Lima         77       4    False
#   ...     ...   ...           ...        ...     ...      ...
#   22106    61    PE    Água Preta          1       0    False
#   22107    70    PE   Águas Belas          3       0     True
#   22108    69    PE   Águas Belas          3       0    False
#   22109    68    PE   Águas Belas          3       0    False
#   22110    67    PE   Águas Belas          3       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   19243                    99990.0       2600054.0
#   19244                    99990.0       2600054.0
#   19245                    99990.0       2600054.0
#   19246                    99990.0       2600054.0
#   19247                    99990.0       2600054.0
#   ...                          ...             ...
#   22106                    36771.0       2600401.0
#   22107                    43443.0       2600500.0
#   22108                    43443.0       2600500.0
#   22109                    43443.0       2600500.0
#   22110                    43443.0       2600500.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   19243                        87.00870      0.0460
#   19244                        87.00870      0.0460
#   19245                        87.00870      0.0460
#   19246                        83.00830      0.0482
#   19247                        77.00770      0.0519
#   ...                               ...         ...
#   22106                         2.71953      0.0000
#   22107                         6.90560      0.0000
#   22108                         6.90560      0.0000
#   22109                         6.90560      0.0000
#   22110                         6.90560      0.0000
#
#   [2868 rows x 10 columns],
#          date state         city  confirmed  deaths  is_last  \
#   17132    70    PI        Altos          9       0     True
#   17133    69    PI        Altos          8       0    False
#   17134    68    PI        Altos          7       0    False
#   17135    67    PI        Altos         10       0    False
#   17136    66    PI        Altos          7       0    False
#   ...     ...   ...          ...        ...     ...      ...
#   18152    62    PI  Água Branca          6       0    False
#   18153    61    PI  Água Branca          4       0    False
#   18154    60    PI  Água Branca          4       0    False
#   18155    59    PI  Água Branca          4       0    False
#   18156    58    PI  Água Branca          3       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   17132                    40524.0       2200400.0
#   17133                    40524.0       2200400.0
#   17134                    40524.0       2200400.0
#   17135                    40524.0       2200400.0
#   17136                    40524.0       2200400.0
#   ...                          ...             ...
#   18152                    17411.0       2200202.0
#   18153                    17411.0       2200202.0
#   18154                    17411.0       2200202.0
#   18155                    17411.0       2200202.0
#   18156                    17411.0       2200202.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   17132                        22.20906         0.0
#   17133                        19.74139         0.0
#   17134                        17.27371         0.0
#   17135                        24.67673         0.0
#   17136                        17.27371         0.0
#   ...                               ...         ...
#   18152                        34.46097         0.0
#   18153                        22.97398         0.0
#   18154                        22.97398         0.0
#   18155                        22.97398         0.0
#   18156                        17.23049         0.0
#
#   [1025 rows x 10 columns],
#          date state    city  confirmed  deaths  is_last  \
#   9302     69    RN   Acari          1       0     True
#   9303     68    RN   Acari          1       0    False
#   9304     67    RN   Acari          1       0    False
#   9305     66    RN   Acari          1       0    False
#   9306     65    RN   Acari          1       0    False
#   ...     ...   ...     ...        ...     ...      ...
#   10804    56    RN  Touros          1       1    False
#   10805    55    RN  Touros          1       1    False
#   10806    54    RN  Touros          1       1    False
#   10807    53    RN  Touros          1       1    False
#   10808    52    RN  Touros          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   9302                     11136.0       2400109.0
#   9303                     11136.0       2400109.0
#   9304                     11136.0       2400109.0
#   9305                     11136.0       2400109.0
#   9306                     11136.0       2400109.0
#   ...                          ...             ...
#   10804                    33287.0       2414407.0
#   10805                    33287.0       2414407.0
#   10806                    33287.0       2414407.0
#   10807                    33287.0       2414407.0
#   10808                    33287.0       2414407.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   9302                          8.97989         0.0
#   9303                          8.97989         0.0
#   9304                          8.97989         0.0
#   9305                          8.97989         0.0
#   9306                          8.97989         0.0
#   ...                               ...         ...
#   10804                         3.00418         1.0
#   10805                         3.00418         1.0
#   10806                         3.00418         1.0
#   10807                         3.00418         1.0
#   10808                         3.00418         0.0
#
#   [1507 rows x 10 columns],
#          date state      city  confirmed  deaths  is_last  \
#   33845    70    SE  Aquidabã          1       0     True
#   33846    69    SE  Aquidabã          1       0    False
#   33847    68    SE  Aquidabã          1       0    False
#   33848    67    SE  Aquidabã          1       0    False
#   33849    66    SE  Aquidabã          1       0    False
#   ...     ...   ...       ...        ...     ...      ...
#   34387    68    SE   Umbaúba          3       0    False
#   34388    67    SE   Umbaúba          2       0    False
#   34389    66    SE   Umbaúba          1       0    False
#   34390    65    SE   Umbaúba          1       0    False
#   34391    63    SE   Umbaúba          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   33845                    21563.0       2800209.0
#   33846                    21563.0       2800209.0
#   33847                    21563.0       2800209.0
#   33848                    21563.0       2800209.0
#   33849                    21563.0       2800209.0
#   ...                          ...             ...
#   34387                    25294.0       2807600.0
#   34388                    25294.0       2807600.0
#   34389                    25294.0       2807600.0
#   34390                    25294.0       2807600.0
#   34391                    25294.0       2807600.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   33845                         4.63757         0.0
#   33846                         4.63757         0.0
#   33847                         4.63757         0.0
#   33848                         4.63757         0.0
#   33849                         4.63757         0.0
#   ...                               ...         ...
#   34387                        11.86052         0.0
#   34388                         7.90701         0.0
#   34389                         3.95351         0.0
#   34390                         3.95351         0.0
#   34391                         3.95351         0.0
#
#   [547 rows x 10 columns]],
#  [     date state        city  confirmed  deaths  is_last  \
#   424    70    AC  Acrelândia         16       1     True
#   425    69    AC  Acrelândia         15       1    False
#   426    68    AC  Acrelândia         15       0    False
#   427    67    AC  Acrelândia         13       0    False
#   428    66    AC  Acrelândia         13       0    False
#   ..    ...   ...         ...        ...     ...      ...
#   678    68    AC      Xapuri          9       0    False
#   679    67    AC      Xapuri          9       0    False
#   680    66    AC      Xapuri          9       0    False
#   681    65    AC      Xapuri          8       0    False
#   682    64    AC      Xapuri          3       0    False
#
#        estimated_population_2019  city_ibge_code  \
#   424                    15256.0       1200013.0
#   425                    15256.0       1200013.0
#   426                    15256.0       1200013.0
#   427                    15256.0       1200013.0
#   428                    15256.0       1200013.0
#   ..                         ...             ...
#   678                    19323.0       1200708.0
#   679                    19323.0       1200708.0
#   680                    19323.0       1200708.0
#   681                    19323.0       1200708.0
#   682                    19323.0       1200708.0
#
#        confirmed_per_100k_inhabitants  death_rate
#   424                       104.87677      0.0625
#   425                        98.32197      0.0667
#   426                        98.32197      0.0000
#   427                        85.21238      0.0000
#   428                        85.21238      0.0000
#   ..                              ...         ...
#   678                        46.57662      0.0000
#   679                        46.57662      0.0000
#   680                        46.57662      0.0000
#   681                        41.40144      0.0000
#   682                        15.52554      0.0000
#
#   [259 rows x 10 columns],
#          date state         city  confirmed  deaths  is_last  \
#   51647    70    AM     Alvarães          2       0     True
#   51648    69    AM     Alvarães          1       0    False
#   51649    70    AM      Amaturá         35       1     True
#   51650    69    AM      Amaturá         30       1    False
#   51651    68    AM      Amaturá         25       1    False
#   ...     ...   ...          ...        ...     ...      ...
#   52747    65    AM  Urucurituba          3       0    False
#   52748    64    AM  Urucurituba          3       0    False
#   52749    63    AM  Urucurituba          3       0    False
#   52750    62    AM  Urucurituba          2       0    False
#   52751    61    AM  Urucurituba          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   51647                    16041.0       1300029.0
#   51648                    16041.0       1300029.0
#   51649                    11536.0       1300060.0
#   51650                    11536.0       1300060.0
#   51651                    11536.0       1300060.0
#   ...                          ...             ...
#   52747                    23065.0       1304401.0
#   52748                    23065.0       1304401.0
#   52749                    23065.0       1304401.0
#   52750                    23065.0       1304401.0
#   52751                    23065.0       1304401.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   51647                        12.46805      0.0000
#   51648                         6.23403      0.0000
#   51649                       303.39806      0.0286
#   51650                       260.05548      0.0333
#   51651                       216.71290      0.0400
#   ...                               ...         ...
#   52747                        13.00672      0.0000
#   52748                        13.00672      0.0000
#   52749                        13.00672      0.0000
#   52750                         8.67115      0.0000
#   52751                         4.33557      0.0000
#
#   [1105 rows x 10 columns],
#          date state             city  confirmed  deaths  is_last  \
#   39634    70    AP            Amapá          2       0     True
#   39635    69    AP            Amapá          2       0    False
#   39636    68    AP            Amapá          2       0    False
#   39637    67    AP            Amapá          2       0    False
#   39638    66    AP            Amapá          2       0    False
#   ...     ...   ...              ...        ...     ...      ...
#   39902    53    AP  Vitória do Jari          2       0    False
#   39903    52    AP  Vitória do Jari          2       0    False
#   39904    51    AP  Vitória do Jari          2       0    False
#   39905    50    AP  Vitória do Jari          2       0    False
#   39906    49    AP  Vitória do Jari          2       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   39634                     9109.0       1600105.0
#   39635                     9109.0       1600105.0
#   39636                     9109.0       1600105.0
#   39637                     9109.0       1600105.0
#   39638                     9109.0       1600105.0
#   ...                          ...             ...
#   39902                    15931.0       1600808.0
#   39903                    15931.0       1600808.0
#   39904                    15931.0       1600808.0
#   39905                    15931.0       1600808.0
#   39906                    15931.0       1600808.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   39634                        21.95631         0.0
#   39635                        21.95631         0.0
#   39636                        21.95631         0.0
#   39637                        21.95631         0.0
#   39638                        21.95631         0.0
#   ...                               ...         ...
#   39902                        12.55414         0.0
#   39903                        12.55414         0.0
#   39904                        12.55414         0.0
#   39905                        12.55414         0.0
#   39906                        12.55414         0.0
#
#   [273 rows x 10 columns],
#          date state        city  confirmed  deaths  is_last  \
#   22160    70    PA  Abaetetuba         58       0     True
#   22161    69    PA  Abaetetuba         56       0    False
#   22162    68    PA  Abaetetuba         48       0    False
#   22163    67    PA  Abaetetuba         42       0    False
#   22164    66    PA  Abaetetuba         35       0    False
#   ...     ...   ...         ...        ...     ...      ...
#   24159    53    PA      Óbidos          1       0    False
#   24160    52    PA      Óbidos          1       0    False
#   24161    51    PA      Óbidos          1       0    False
#   24162    50    PA      Óbidos          1       0    False
#   24163    49    PA      Óbidos          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   22160                   157698.0       1500107.0
#   22161                   157698.0       1500107.0
#   22162                   157698.0       1500107.0
#   22163                   157698.0       1500107.0
#   22164                   157698.0       1500107.0
#   ...                          ...             ...
#   24159                    52137.0       1505106.0
#   24160                    52137.0       1505106.0
#   24161                    52137.0       1505106.0
#   24162                    52137.0       1505106.0
#   24163                    52137.0       1505106.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   22160                        36.77916         0.0
#   22161                        35.51091         0.0
#   22162                        30.43793         0.0
#   22163                        26.63318         0.0
#   22164                        22.19432         0.0
#   ...                               ...         ...
#   24159                         1.91802         0.0
#   24160                         1.91802         0.0
#   24161                         1.91802         0.0
#   24162                         1.91802         0.0
#   24163                         1.91802         0.0
#
#   [2004 rows x 10 columns],
#         date state                     city  confirmed  deaths  is_last  \
#   8587    70    RO    Alta Floresta D'Oeste          1       0     True
#   8588    69    RO    Alta Floresta D'Oeste          1       0    False
#   8589    68    RO    Alta Floresta D'Oeste          1       0    False
#   8590    67    RO    Alta Floresta D'Oeste          1       0    False
#   8591    70    RO  Alto Alegre dos Parecis          4       0     True
#   ...    ...   ...                      ...        ...     ...      ...
#   8971    44    RO                  Vilhena          1       0    False
#   8972    43    RO                  Vilhena          1       0    False
#   8973    42    RO                  Vilhena          1       0    False
#   8974    41    RO                  Vilhena          1       0    False
#   8975    40    RO                  Vilhena          1       0    False
#
#         estimated_population_2019  city_ibge_code  \
#   8587                    22945.0       1100015.0
#   8588                    22945.0       1100015.0
#   8589                    22945.0       1100015.0
#   8590                    22945.0       1100015.0
#   8591                    13241.0       1100379.0
#   ...                         ...             ...
#   8971                    99854.0       1100304.0
#   8972                    99854.0       1100304.0
#   8973                    99854.0       1100304.0
#   8974                    99854.0       1100304.0
#   8975                    99854.0       1100304.0
#
#         confirmed_per_100k_inhabitants  death_rate
#   8587                         4.35825         0.0
#   8588                         4.35825         0.0
#   8589                         4.35825         0.0
#   8590                         4.35825         0.0
#   8591                        30.20920         0.0
#   ...                              ...         ...
#   8971                         1.00146         0.0
#   8972                         1.00146         0.0
#   8973                         1.00146         0.0
#   8974                         1.00146         0.0
#   8975                         1.00146         0.0
#
#   [389 rows x 10 columns],
#         date state         city  confirmed  deaths  is_last  \
#   9019    70    RR  Alto Alegre          8       1     True
#   9020    69    RR  Alto Alegre          5       1    False
#   9021    68    RR  Alto Alegre          5       1    False
#   9022    65    RR  Alto Alegre          5       1    False
#   9023    64    RR  Alto Alegre          4       1    False
#   ...    ...   ...          ...        ...     ...      ...
#   9251    55    RR     São Luiz          1       0    False
#   9252    54    RR     São Luiz          1       0    False
#   9253    53    RR     São Luiz          1       0    False
#   9254    52    RR     São Luiz          1       0    False
#   9255    70    RR     Uiramutã          0       0     True
#
#         estimated_population_2019  city_ibge_code  \
#   9019                    15510.0       1400050.0
#   9020                    15510.0       1400050.0
#   9021                    15510.0       1400050.0
#   9022                    15510.0       1400050.0
#   9023                    15510.0       1400050.0
#   ...                         ...             ...
#   9251                     7986.0       1400605.0
#   9252                     7986.0       1400605.0
#   9253                     7986.0       1400605.0
#   9254                     7986.0       1400605.0
#   9255                    10559.0       1400704.0
#
#         confirmed_per_100k_inhabitants  death_rate
#   9019                        51.57963       0.125
#   9020                        32.23727       0.200
#   9021                        32.23727       0.200
#   9022                        32.23727       0.200
#   9023                        25.78981       0.250
#   ...                              ...         ...
#   9251                        12.52191       0.000
#   9252                        12.52191       0.000
#   9253                        12.52191       0.000
#   9254                        12.52191       0.000
#   9255                             NaN       0.000
#
#   [237 rows x 10 columns],
#        date state           city  confirmed  deaths  is_last  \
#   48     69    TO  Aguiarnópolis          1       1     True
#   49     68    TO  Aguiarnópolis          1       1    False
#   50     67    TO  Aguiarnópolis          1       0    False
#   51     69    TO         Ananás          1       0     True
#   52     68    TO         Ananás          1       0    False
#   ..    ...   ...            ...        ...     ...      ...
#   369    67    TO   Wanderlândia          4       0    False
#   370    66    TO   Wanderlândia          4       0    False
#   371    65    TO   Wanderlândia          3       0    False
#   372    64    TO   Wanderlândia          1       0    False
#   373    63    TO   Wanderlândia          1       0    False
#
#        estimated_population_2019  city_ibge_code  \
#   48                      6733.0       1700301.0
#   49                      6733.0       1700301.0
#   50                      6733.0       1700301.0
#   51                      9549.0       1701002.0
#   52                      9549.0       1701002.0
#   ..                         ...             ...
#   369                    11683.0       1722081.0
#   370                    11683.0       1722081.0
#   371                    11683.0       1722081.0
#   372                    11683.0       1722081.0
#   373                    11683.0       1722081.0
#
#        confirmed_per_100k_inhabitants  death_rate
#   48                         14.85222         1.0
#   49                         14.85222         1.0
#   50                         14.85222         0.0
#   51                         10.47230         0.0
#   52                         10.47230         0.0
#   ..                              ...         ...
#   369                        34.23778         0.0
#   370                        34.23778         0.0
#   371                        25.67834         0.0
#   372                         8.55945         0.0
#   373                         8.55945         0.0
#
#   [326 rows x 10 columns]],
#  [       date state            city  confirmed  deaths  is_last  \
#   34454    70    ES  Afonso Cláudio         14       2     True
#   34455    69    ES  Afonso Cláudio         14       2    False
#   34456    68    ES  Afonso Cláudio         13       2    False
#   34457    67    ES  Afonso Cláudio         11       2    False
#   34458    66    ES  Afonso Cláudio         10       2    False
#   ...     ...   ...             ...        ...     ...      ...
#   36061    67    ES    Águia Branca          0       0    False
#   36062    66    ES    Águia Branca          0       0    False
#   36063    65    ES    Águia Branca          0       0    False
#   36064    64    ES    Águia Branca          0       0    False
#   36065    63    ES    Águia Branca          0       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   34454                    30586.0       3200102.0
#   34455                    30586.0       3200102.0
#   34456                    30586.0       3200102.0
#   34457                    30586.0       3200102.0
#   34458                    30586.0       3200102.0
#   ...                          ...             ...
#   36061                     9642.0       3200136.0
#   36062                     9642.0       3200136.0
#   36063                     9642.0       3200136.0
#   36064                     9642.0       3200136.0
#   36065                     9642.0       3200136.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   34454                        45.77258      0.1429
#   34455                        45.77258      0.1429
#   34456                        42.50311      0.1538
#   34457                        35.96417      0.1818
#   34458                        32.69470      0.2000
#   ...                               ...         ...
#   36061                             NaN      0.0000
#   36062                             NaN      0.0000
#   36063                             NaN      0.0000
#   36064                             NaN      0.0000
#   36065                             NaN      0.0000
#
#   [1612 rows x 10 columns],
#          date state    city  confirmed  deaths  is_last  \
#   27438    70    MG  Abaeté          1       0     True
#   27439    69    MG  Abaeté          1       0    False
#   27440    68    MG  Abaeté          1       0    False
#   27441    67    MG  Abaeté          1       0    False
#   27442    66    MG  Abaeté          1       0    False
#   ...     ...   ...     ...        ...     ...      ...
#   32030    58    MG  Viçosa          0       0    False
#   32031    57    MG  Viçosa          0       0    False
#   32032    56    MG  Viçosa          0       0    False
#   32033    55    MG  Viçosa          0       0    False
#   32034    54    MG  Viçosa          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   27438                    23237.0       3100203.0
#   27439                    23237.0       3100203.0
#   27440                    23237.0       3100203.0
#   27441                    23237.0       3100203.0
#   27442                    23237.0       3100203.0
#   ...                          ...             ...
#   32030                    78846.0       3171303.0
#   32031                    78846.0       3171303.0
#   32032                    78846.0       3171303.0
#   32033                    78846.0       3171303.0
#   32034                    78846.0       3171303.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   27438                         4.30348         0.0
#   27439                         4.30348         0.0
#   27440                         4.30348         0.0
#   27441                         4.30348         0.0
#   27442                         4.30348         0.0
#   ...                               ...         ...
#   32030                             NaN         0.0
#   32031                             NaN         0.0
#   32032                             NaN         0.0
#   32033                             NaN         0.0
#   32034                         1.26830         0.0
#
#   [4597 rows x 10 columns],
#          date state            city  confirmed  deaths  is_last  \
#   10863    70    RJ  Angra dos Reis         58       0     True
#   10864    69    RJ  Angra dos Reis         56       0    False
#   10865    68    RJ  Angra dos Reis         56       0    False
#   10866    67    RJ  Angra dos Reis         53       0    False
#   10867    66    RJ  Angra dos Reis         48       0    False
#   ...     ...   ...             ...        ...     ...      ...
#   13344    32    RJ   Volta Redonda         11       1    False
#   13345    31    RJ   Volta Redonda          9       1    False
#   13346    30    RJ   Volta Redonda          7       0    False
#   13347    29    RJ   Volta Redonda          6       0    False
#   13348    28    RJ   Volta Redonda          4       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   10863                   203785.0       3300100.0
#   10864                   203785.0       3300100.0
#   10865                   203785.0       3300100.0
#   10866                   203785.0       3300100.0
#   10867                   203785.0       3300100.0
#   ...                          ...             ...
#   13344                   273012.0       3306305.0
#   13345                   273012.0       3306305.0
#   13346                   273012.0       3306305.0
#   13347                   273012.0       3306305.0
#   13348                   273012.0       3306305.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   10863                        28.46137      0.0000
#   10864                        27.47994      0.0000
#   10865                        27.47994      0.0000
#   10866                        26.00780      0.0000
#   10867                        23.55424      0.0000
#   ...                               ...         ...
#   13344                         4.02913      0.0909
#   13345                         3.29656      0.1111
#   13346                         2.56399      0.0000
#   13347                         2.19771      0.0000
#   13348                         1.46514      0.0000
#
#   [2486 rows x 10 columns],
#          date state             city  confirmed  deaths  is_last  \
#   43621    70    SP       Adamantina          7       0     True
#   43622    69    SP       Adamantina          6       0    False
#   43623    68    SP       Adamantina          6       0    False
#   43624    67    SP       Adamantina          6       0    False
#   43625    66    SP       Adamantina          5       0    False
#   ...     ...   ...              ...        ...     ...      ...
#   51592    67    SP  Álvares Machado          1       0    False
#   51593    66    SP  Álvares Machado          1       0    False
#   51594    65    SP  Álvares Machado          1       0    False
#   51595    64    SP  Álvares Machado          1       0    False
#   51596    63    SP  Álvares Machado          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   43621                    35068.0       3500105.0
#   43622                    35068.0       3500105.0
#   43623                    35068.0       3500105.0
#   43624                    35068.0       3500105.0
#   43625                    35068.0       3500105.0
#   ...                          ...             ...
#   51592                    24915.0       3501301.0
#   51593                    24915.0       3501301.0
#   51594                    24915.0       3501301.0
#   51595                    24915.0       3501301.0
#   51596                    24915.0       3501301.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   43621                        19.96122         0.0
#   43622                        17.10962         0.0
#   43623                        17.10962         0.0
#   43624                        17.10962         0.0
#   43625                        14.25801         0.0
#   ...                               ...         ...
#   51592                         4.01365         0.0
#   51593                         4.01365         0.0
#   51594                         4.01365         0.0
#   51595                         4.01365         0.0
#   51596                         4.01365         0.0
#
#   [7976 rows x 10 columns]],
#  [       date state                 city  confirmed  deaths  is_last  \
#   13402    70    PR  Almirante Tamandaré          7       0     True
#   13403    69    PR  Almirante Tamandaré          7       0    False
#   13404    68    PR  Almirante Tamandaré          7       0    False
#   13405    67    PR  Almirante Tamandaré          7       0    False
#   13406    66    PR  Almirante Tamandaré          7       0    False
#   ...     ...   ...                  ...        ...     ...      ...
#   17080    46    PR             Vitorino          1       0    False
#   17081    45    PR             Vitorino          1       0    False
#   17082    44    PR             Vitorino          1       0    False
#   17083    43    PR             Vitorino          1       0    False
#   17084    42    PR             Vitorino          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   13402                   118623.0       4100400.0
#   13403                   118623.0       4100400.0
#   13404                   118623.0       4100400.0
#   13405                   118623.0       4100400.0
#   13406                   118623.0       4100400.0
#   ...                          ...             ...
#   17080                     6838.0       4128708.0
#   17081                     6838.0       4128708.0
#   17082                     6838.0       4128708.0
#   17083                     6838.0       4128708.0
#   17084                     6838.0       4128708.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   13402                         5.90105         0.0
#   13403                         5.90105         0.0
#   13404                         5.90105         0.0
#   13405                         5.90105         0.0
#   13406                         5.90105         0.0
#   ...                               ...         ...
#   17080                        14.62416         0.0
#   17081                        14.62416         0.0
#   17082                        14.62416         0.0
#   17083                        14.62416         0.0
#   17084                        14.62416         0.0
#
#   [3683 rows x 10 columns],
#         date state       city  confirmed  deaths  is_last  \
#   737     70    RS  Ajuricaba          1       0     True
#   738     69    RS  Ajuricaba          1       0    False
#   739     68    RS  Ajuricaba          1       0    False
#   740     67    RS  Ajuricaba          1       0    False
#   741     66    RS  Ajuricaba          1       0    False
#   ...    ...   ...        ...        ...     ...      ...
#   4753    67    RS  Xangri-lá          1       0    False
#   4754    66    RS  Xangri-lá          1       0    False
#   4755    65    RS  Xangri-lá          1       0    False
#   4756    64    RS  Xangri-lá          1       0    False
#   4757    63    RS  Xangri-lá          1       0    False
#
#         estimated_population_2019  city_ibge_code  \
#   737                      7024.0       4300208.0
#   738                      7024.0       4300208.0
#   739                      7024.0       4300208.0
#   740                      7024.0       4300208.0
#   741                      7024.0       4300208.0
#   ...                         ...             ...
#   4753                    16408.0       4323804.0
#   4754                    16408.0       4323804.0
#   4755                    16408.0       4323804.0
#   4756                    16408.0       4323804.0
#   4757                    16408.0       4323804.0
#
#         confirmed_per_100k_inhabitants  death_rate
#   737                         14.23690         0.0
#   738                         14.23690         0.0
#   739                         14.23690         0.0
#   740                         14.23690         0.0
#   741                         14.23690         0.0
#   ...                              ...         ...
#   4753                         6.09459         0.0
#   4754                         6.09459         0.0
#   4755                         6.09459         0.0
#   4756                         6.09459         0.0
#   4757                         6.09459         0.0
#
#   [4021 rows x 10 columns],
#         date state              city  confirmed  deaths  is_last  \
#   4813    70    SC   Alto Bela Vista          2       0     True
#   4814    69    SC   Alto Bela Vista          2       0    False
#   4815    68    SC   Alto Bela Vista          2       0    False
#   4816    67    SC   Alto Bela Vista          2       0    False
#   4817    70    SC   Anita Garibaldi          1       0     True
#   ...    ...   ...               ...        ...     ...      ...
#   8538    67    SC  Águas de Chapecó          2       0    False
#   8539    66    SC  Águas de Chapecó          1       0    False
#   8540    65    SC  Águas de Chapecó          1       0    False
#   8541    64    SC  Águas de Chapecó          1       0    False
#   8542    63    SC  Águas de Chapecó          1       0    False
#
#         estimated_population_2019  city_ibge_code  \
#   4813                     1937.0       4200754.0
#   4814                     1937.0       4200754.0
#   4815                     1937.0       4200754.0
#   4816                     1937.0       4200754.0
#   4817                     7133.0       4201000.0
#   ...                         ...             ...
#   8538                     6486.0       4200507.0
#   8539                     6486.0       4200507.0
#   8540                     6486.0       4200507.0
#   8541                     6486.0       4200507.0
#   8542                     6486.0       4200507.0
#
#         confirmed_per_100k_inhabitants  death_rate
#   4813                       103.25245         0.0
#   4814                       103.25245         0.0
#   4815                       103.25245         0.0
#   4816                       103.25245         0.0
#   4817                        14.01935         0.0
#   ...                              ...         ...
#   8538                        30.83565         0.0
#   8539                        15.41782         0.0
#   8540                        15.41782         0.0
#   8541                        15.41782         0.0
#   8542                        15.41782         0.0
#
#   [3730 rows x 10 columns]],
#  [       date state                    city  confirmed  deaths  is_last  \
#   39489    69    DF                Brasília       1670      33     True
#   39490    68    DF                Brasília       1616      33    False
#   39491    67    DF                Brasília       1521      32    False
#   39492    66    DF                Brasília       1458      31    False
#   39493    65    DF                Brasília       1342      30    False
#   ...     ...   ...                     ...        ...     ...      ...
#   39582    34    DF  Importados/Indefinidos         27       0    False
#   39583    33    DF  Importados/Indefinidos         28       0    False
#   39584    32    DF  Importados/Indefinidos         35       0    False
#   39585    31    DF  Importados/Indefinidos         30       0    False
#   39586    30    DF  Importados/Indefinidos         30       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   39489                  3015268.0       5300108.0
#   39490                  3015268.0       5300108.0
#   39491                  3015268.0       5300108.0
#   39492                  3015268.0       5300108.0
#   39493                  3015268.0       5300108.0
#   ...                          ...             ...
#   39582                        NaN             NaN
#   39583                        NaN             NaN
#   39584                        NaN             NaN
#   39585                        NaN             NaN
#   39586                        NaN             NaN
#
#          confirmed_per_100k_inhabitants  death_rate
#   39489                        55.38479      0.0198
#   39490                        53.59391      0.0204
#   39491                        50.44328      0.0210
#   39492                        48.35391      0.0213
#   39493                        44.50682      0.0224
#   ...                               ...         ...
#   39582                             NaN      0.0000
#   39583                             NaN      0.0000
#   39584                             NaN      0.0000
#   39585                             NaN      0.0000
#   39586                             NaN      0.0000
#
#   [98 rows x 10 columns],
#          date state                   city  confirmed  deaths  is_last  \
#   32090    70    GO               Aloândia          1       0     True
#   32091    69    GO               Aloândia          1       0    False
#   32092    68    GO               Aloândia          1       0    False
#   32093    67    GO               Aloândia          1       0    False
#   32094    66    GO               Aloândia          1       0    False
#   ...     ...   ...                    ...        ...     ...      ...
#   33798    36    GO  Águas Lindas de Goiás          1       0    False
#   33799    35    GO  Águas Lindas de Goiás          1       0    False
#   33800    34    GO  Águas Lindas de Goiás          1       0    False
#   33801    33    GO  Águas Lindas de Goiás          1       0    False
#   33802    32    GO  Águas Lindas de Goiás          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   32090                     1995.0       5200506.0
#   32091                     1995.0       5200506.0
#   32092                     1995.0       5200506.0
#   32093                     1995.0       5200506.0
#   32094                     1995.0       5200506.0
#   ...                          ...             ...
#   33798                   212440.0       5200258.0
#   33799                   212440.0       5200258.0
#   33800                   212440.0       5200258.0
#   33801                   212440.0       5200258.0
#   33802                   212440.0       5200258.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   32090                        50.12531         0.0
#   32091                        50.12531         0.0
#   32092                        50.12531         0.0
#   32093                        50.12531         0.0
#   32094                        50.12531         0.0
#   ...                               ...         ...
#   33798                         0.47072         0.0
#   33799                         0.47072         0.0
#   33800                         0.47072         0.0
#   33801                         0.47072         0.0
#   33802                         0.47072         0.0
#
#   [1713 rows x 10 columns],
#          date state           city  confirmed  deaths  is_last  \
#   24208    70    MT  Alta Floresta          2       0     True
#   24209    69    MT  Alta Floresta          2       0    False
#   24210    68    MT  Alta Floresta          2       0    False
#   24211    67    MT  Alta Floresta          2       0    False
#   24212    66    MT  Alta Floresta          2       0    False
#   ...     ...   ...            ...        ...     ...      ...
#   25045    31    MT  Várzea Grande          2       0    False
#   25046    30    MT  Várzea Grande          2       0    False
#   25047    29    MT  Várzea Grande          2       0    False
#   25048    28    MT  Várzea Grande          1       0    False
#   25049    27    MT  Várzea Grande          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   24208                    51782.0       5100250.0
#   24209                    51782.0       5100250.0
#   24210                    51782.0       5100250.0
#   24211                    51782.0       5100250.0
#   24212                    51782.0       5100250.0
#   ...                          ...             ...
#   25045                   284971.0       5108402.0
#   25046                   284971.0       5108402.0
#   25047                   284971.0       5108402.0
#   25048                   284971.0       5108402.0
#   25049                   284971.0       5108402.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   24208                         3.86235         0.0
#   24209                         3.86235         0.0
#   24210                         3.86235         0.0
#   24211                         3.86235         0.0
#   24212                         3.86235         0.0
#   ...                               ...         ...
#   25045                         0.70183         0.0
#   25046                         0.70183         0.0
#   25047                         0.70183         0.0
#   25048                         0.35091         0.0
#   25049                         0.35091         0.0
#
#   [842 rows x 10 columns],
#          date state         city  confirmed  deaths  is_last  \
#   25103    70    MS  Alcinópolis          1       0     True
#   25104    69    MS  Alcinópolis          1       0    False
#   25105    68    MS  Alcinópolis          1       0    False
#   25106    67    MS  Alcinópolis          1       0    False
#   25107    66    MS  Alcinópolis          1       0    False
#   ...     ...   ...          ...        ...     ...      ...
#   25746    40    MS  Três Lagoas          3       0    False
#   25747    39    MS  Três Lagoas          1       0    False
#   25748    38    MS  Três Lagoas          1       0    False
#   25749    37    MS  Três Lagoas          1       0    False
#   25750    36    MS  Três Lagoas          1       0    False
#
#          estimated_population_2019  city_ibge_code  \
#   25103                     5343.0       5000252.0
#   25104                     5343.0       5000252.0
#   25105                     5343.0       5000252.0
#   25106                     5343.0       5000252.0
#   25107                     5343.0       5000252.0
#   ...                          ...             ...
#   25746                   121388.0       5008305.0
#   25747                   121388.0       5008305.0
#   25748                   121388.0       5008305.0
#   25749                   121388.0       5008305.0
#   25750                   121388.0       5008305.0
#
#          confirmed_per_100k_inhabitants  death_rate
#   25103                        18.71608         0.0
#   25104                        18.71608         0.0
#   25105                        18.71608         0.0
#   25106                        18.71608         0.0
#   25107                        18.71608         0.0
#   ...                               ...         ...
#   25746                         2.47141         0.0
#   25747                         0.82380         0.0
#   25748                         0.82380         0.0
#   25749                         0.82380         0.0
#   25750                         0.82380         0.0
#
#   [648 rows x 10 columns]]]

# %%
for f in range(3, 5) :
    plt.rc('font', size=14)
    plt.rcParams['figure.figsize'] = [14, 10]
    plt.tick_params(axis = "both", which = "both", bottom = "off", top = "off",    
                    labelbottom = "on", left = "off", right = "off", labelleft = "on")
    
    plt.gca().spines["top"].set_visible(False)    
    plt.gca().spines["right"].set_visible(False)
    plt.gca().get_xaxis().tick_bottom()    
    plt.gca().get_yaxis().tick_left()
    
    for r in range(len(Regiao)) :
        x_max = 0
        y_max = 0
        for e in range(len(Regiao[r])) :
            cit = list(df_regioes[r][e].iloc[:, 2])
            for c in range(len(Regiao[r][e])) :
                # Real data
                x = list(df_regioes[r][e].iloc[:, 0])
                y = list(df_regioes[r][e].iloc[:, f])

                if max(x) > x_max :
                    x_max = max(x)
                if max(y) > y_max :
                    y_max = max(y)

                if c < 1 :
                    plt.plot(x, y, marker = ' ', label = cit[c], color = color[c], lw = 2.5)
                    plt.text(max(x) * 1.01, (2 * y[-1] - y[-2]), cit[c], color = color[c], fontsize = 14)
                elif c == 1 :
                    plt.plot(x, y, marker = ' ', label = 'Outros municípios', color = 'gray', lw = 1.5)
                else :
                    plt.plot(x, y, marker = ' ', color = 'gray', lw = 1.5)

                if f == 2 :
                    ytick = 50
                else :
                    ytick = 5

        #plt.yticks(range(0, y_max, ytick), fontsize=14)    
        #plt.xticks(range(0, x_max, 5), fontsize = 14)

        #for t in range(0, y_max, ytick) :    
        #     plt.plot(range(20, x_max), [t] * len(range(20, x_max)), linestyle = "dashed", lw = 0.5, color = "black", alpha = 0.3)

        plt.xlim(20, x_max * 1.03)
        plt.ylim(0, y_max * 1.03)
        plt.title(label[f] + " na Região " + str(Regiao[r]))
        plt.legend(loc = 2)
        #plt.yscale('log')
        plt.xlabel("Dias após 25/02/2020")
        plt.ylabel(label[f])
        #plt.savefig(label[f] + " COVID19 Paraiba.png")
        plt.show()

# %%
df_PB = []

paraiba_c = list(df_paraiba.sort_values("confirmed", ascending = False)['city'].unique())
df_PB = paraiba_c

for c in range(len(paraiba_c)) :
    df_PB[c] = df_paraiba.loc[df_paraiba['city'] == paraiba_c[c], :].drop(['estimated_population_2019'], axis = 1)
    df_PB[c] = df_PB[c].sort_values('date', ascending = True)
    df_PB[c].reset_index(drop = True, inplace = True)
    
paraiba_c = list(df_paraiba.sort_values("confirmed", ascending = False)['city'].unique())

# %%
for f in range(2, 4) :
    plt.rc('font', size=14)
    plt.rcParams['figure.figsize'] = [14, 10]
    plt.tick_params(axis = "both", which = "both", bottom = "off", top = "off",    
                    labelbottom = "on", left = "off", right = "off", labelleft = "on")
    
    plt.gca().spines["top"].set_visible(False)    
    plt.gca().spines["right"].set_visible(False)
    plt.gca().get_xaxis().tick_bottom()    
    plt.gca().get_yaxis().tick_left()
    
    x_max = 0
    y_max = 0
    
    for c in range(len(paraiba_c)) :

        # Real data
        x = list(df_PB[c].iloc[:, 0])
        y = list(df_PB[c].iloc[:, f])
        
        if max(x) > x_max :
            x_max = max(x)
        if max(y) > y_max :
            y_max = max(y)
  
        if c < 5 :
            plt.plot(x, y, marker = ' ', label = paraiba_c[c], color = color[c], lw = 2.5)
            plt.text(max(x) * 1.01, (2 * y[-1] - y[-2]), paraiba_c[c], color = color[c], fontsize = 14)
        elif c == 5 :
            plt.plot(x, y, marker = ' ', label = 'Outros municípios', color = 'gray', lw = 1.5)
        else :
            plt.plot(x, y, marker = ' ', color = 'gray', lw = 1.5)
      
        if f == 2 :
            ytick = 50
        else :
            ytick = 5
    
    plt.yticks(range(0, y_max, ytick), fontsize=14)    
    plt.xticks(range(0, x_max, 5), fontsize = 14)
    
    for t in range(0, y_max, ytick) :    
         plt.plot(range(20, x_max), [t] * len(range(20, x_max)), linestyle = "dashed", lw = 0.5, color = "black", alpha = 0.3)

    plt.xlim(20, x_max * 1.03)
    plt.ylim(0, y_max * 1.03)
    plt.title(label[f] + " na Paraíba")
    plt.legend(loc = 2)
    #plt.yscale('log')
    plt.xlabel("Dias após 25/02/2020")
    plt.ylabel(label[f])
    plt.savefig(label[f] + " COVID19 Paraiba.png")
    plt.show()

# %%
df_hoje = df.loc[(df["is_last"] == True), :].drop(['date', 'is_last'], axis = 1)
df_hoje = df_hoje.loc[(df_hoje["place_type"] == 'city'), :]
df_hoje = df_hoje.loc[(df_hoje["city"] != 'Importados/Indefinidos'), :]
df_hoje['city_ibge_code'] = df_hoje['city_ibge_code'].astype(int).astype(str)

# %%
bins = list(df_hoje['confirmed'].quantile([0, 0.97, 0.99, 0.998, 1]))

mapa_casos = folium.Map(
    width = 800, height = 500,
    location = [-15.77972, -47.92972], #[-7, -36.75], # centro paraiba 
    zoom_start = 4,
    tiles = 'cartodbpositron'
)

mapa_casos.choropleth(
    geo_data = geo,
    name = 'choropleth',
    data = df_hoje,
    columns = ['city_ibge_code', 'confirmed'],
    key_on = 'feature.properties.id',
    fill_color = 'YlOrRd',
    fill_opacity = 0.7,
    nan_fill_color = 'gray',
    nan_fill_opacity = 0.1,
    line_opacity = 0.0,
    legend_name = 'Casos Confirmados',
    legend_fontsize = '14',
    bins = [0, 10, 100, 1000, 10000, 30000]
)
folium.LayerControl().add_to(mapa_casos)

mapa_casos.save('index.html')
mapa_casos

# %%
df_UF = []

estados = list(df_estados.sort_values("confirmed", ascending = False)['state'].unique())
df_UF = estados

for e in range(27) :
    df_UF[e] = df_estados.loc[df_estados['state'] == estados[e], :].drop(['estimated_population_2019', 'is_last'], axis = 1)
    df_UF[e] = df_UF[e].sort_values('date', ascending = True)
    df_UF[e].reset_index(drop = True, inplace = True)
    
estados = list(df_estados.sort_values("confirmed", ascending = False)['state'].unique())

# %%
label = ["Dia", "Estado", "Casos Confirmados", "Óbitos Confirmados", "Incidência de Casos", "Mortalidade"]
color = ['#e8615d', '#f49436', '#2d9de5', '#3bbdbd', '#634792']

for f in range(2, 4) :
    plt.rc('font', size=14)
    plt.rcParams['figure.figsize'] = [14, 10]
    plt.tick_params(axis = "both", which = "both", bottom = "off", top = "off",    
                    labelbottom = "on", left = "off", right = "off", labelleft = "on")
    
    plt.gca().spines["top"].set_visible(False)    
    plt.gca().spines["right"].set_visible(False)
    plt.gca().get_xaxis().tick_bottom()    
    plt.gca().get_yaxis().tick_left()
    
    # Brasil data
#     x = range(max(df_Brasil.index))
#     y = list(df_Brasil.iloc[x, f - 2])
#     plt.plot(x, y, marker = ' ', color = 'black', label = "Brasil", lw = 2.5) 
#     plt.text(max(x) * 1.01, (2 * y[-1] - y[-2]), "Brasil", color = "black", fontsize = 14)
    
    x_max = max(x)
    y_max = max(y)
    for e in range(27) :

        # Real data
        x = list(df_UF[e].iloc[:, 0])
        y = list(df_UF[e].iloc[:, f])
        
        if max(x) > x_max :
            x_max = max(x)
        if max(y) > y_max :
            y_max = max(y)
  
        if e < 5 :
            plt.plot(x, y, marker = ' ', label = estados[e], color = color[e], lw = 2.5)
            plt.text(max(x) * 1.01, (2 * y[-1] - y[-2]), estados[e], color = color[e], fontsize = 14)
        elif e == 5 :
            plt.plot(x, y, marker = ' ', label = 'Outros estados', color = 'gray', lw = 1.5)
        else :
            plt.plot(x, y, marker = ' ', color = 'gray', lw = 1.5)
            
    ytick = 1000 * int(0.0001 * y_max)
    if ytick == 0 : 
        ytick = 100 * int(0.001 * y_max)
   
    plt.yticks(range(0, y_max, ytick), fontsize=14)    
    plt.xticks(range(0, x_max, 5), fontsize = 14)
    
    for t in range(0, y_max, ytick) :    
         plt.plot(range(20, x_max), [t] * len(range(20, x_max)), linestyle = "dashed", lw = 0.5, color = "black", alpha = 0.3)

    plt.xlim(20, x_max * 1.03)
    plt.ylim(0, y_max * 1.03)
    plt.title(label[f] + " no Brasil")
    plt.legend(loc = 2)
    #plt.yscale('log')
    plt.xlabel("Dias após 25/02/2020")
    plt.ylabel(label[f])
    plt.savefig(label[f] + " COVID19 Brasil.png")
    plt.show()

# %%
label = ["Dia", "Estado", "Casos Confirmados", "Óbitos Confirmados", "Incidência de Casos", "Mortalidade"]
color = ['#e8615d', '#f49436', '#2d9de5', '#3bbdbd', '#634792']

for f in range(2, 4) :
    plt.rc('font', size=14)
    plt.rcParams['figure.figsize'] = [14, 10]
    #plt.tick_params(axis = "both", which = "both", bottom = "off", top = "off",    
    #                labelbottom = "on", left = "off", right = "off", labelleft = "on")
    
    plt.gca().spines["top"].set_visible(False)    
    plt.gca().spines["right"].set_visible(False)
    plt.gca().get_xaxis().tick_bottom()    
    plt.gca().get_yaxis().tick_left()
    plt.grid(True, axis = 'y')
    # Brasil data
    x = range(max(df_Brasil.index))
    y = list(df_Brasil.iloc[x, f - 2])
    plt.plot(x, y, marker = ' ', color = 'black', label = "Brasil", lw = 2.5) 
    plt.text(max(x) * 1.01, (2 * y[-1] - y[-2]), "Brasil", color = "black", fontsize = 14)
    
    x_max = max(x)
    y_max = max(y)
    for e in range(27) :

        # Real data
        x = list(df_UF[e].iloc[:, 0])
        y = list(df_UF[e].iloc[:, f])
        
        if max(x) > x_max :
            x_max = max(x)
        if max(y) > y_max :
            y_max = max(y)
  
        if e < 5 :
            plt.plot(x, y, marker = ' ', label = estados[e], color = color[e], lw = 2.5)
            plt.text(max(x) * 1.01, (2 * y[-1] - y[-2]), estados[e], color = color[e], fontsize = 14)
        elif e == 5 :
            plt.plot(x, y, marker = ' ', label = 'Outros estados', color = 'gray', lw = 1.5)
        else :
            plt.plot(x, y, marker = ' ', color = 'gray', lw = 1.5)

    plt.xlim(20, x_max * 1.03)
    plt.ylim(1, y_max * 1.1)
    plt.title(label[f] + " no Brasil")
    plt.legend(loc = 2)
    plt.yscale('log')
    plt.xlabel("Dias após 25/02/2020")
    plt.ylabel(label[f])
    plt.savefig(label[f] + " COVID19 Brasil log.png")
    plt.show()
